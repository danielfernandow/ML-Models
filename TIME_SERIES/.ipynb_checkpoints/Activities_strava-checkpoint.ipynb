# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from dateutil import parser
sns.set_theme(style="darkgrid")

from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Objetivos:
#     - Distancia média por mês (todas modalidades).
#     - Média de tempo em movimento;
#     - Agrupar por tipo.
#     - Série histórica por ano.
#     - Média das velocidades médias
#     - Média das velocidades máximas.
#     - Média das elevações(alto e baixo).
#     - Série Temporal

# %%
df = pd.read_json('response.json')

# %%
df.head()
# Out:
#    resource_state                                athlete          name  \
# 0               2  {'id': 31401271, 'resource_state': 1}   Morning Run
# 1               2  {'id': 31401271, 'resource_state': 1}   Morning Run
# 2               2  {'id': 31401271, 'resource_state': 1}  Morning Ride
# 3               2  {'id': 31401271, 'resource_state': 1}  Morning Ride
# 4               2  {'id': 31401271, 'resource_state': 1}   Morning Run
#
#    distance  moving_time  elapsed_time  total_elevation_gain  type  \
# 0    7421.4         2382          2382                    80   Run
# 1    3973.0         1241          1241                    52   Run
# 2   61663.6         8168          8295                   259  Ride
# 3   39816.8         5566          5716                   112  Ride
# 4    4821.2         1413          1417                    28   Run
#
#    workout_type          id  ... heartrate_opt_out  \
# 0           0.0  5256094139  ...             False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   resource_state                 30 non-null     int64
#  1   athlete                        30 non-null     object
#  2   name                           30 non-null     object
#  3   distance                       30 non-null     float64
#  4   moving_time                    30 non-null     int64
#  5   elapsed_time                   30 non-null     int64
#  6   total_elevation_gain           30 non-null     int64
#  7   type                           30 non-null     object
#  8   workout_type                   12 non-null     float64
#  9   id                             30 non-null     int64
#  10  external_id                    30 non-null     object
#  11  upload_id                      30 non-null     int64
# ...

# %%
columns=['distance', 'moving_time','elapsed_time', 'type', 'start_date', 'average_speed', 'max_speed', 'elev_high', 'elev_low']

# %%
base= df.copy()

# %%
base = base[columns]

# %%
#distancia media bike por mes

# %%
def transform_data(date1):
    datee=''
    date_t = parser.parse(date1)
    datee = date_t.date()
    return str(datee)

# %%
base['start_date'] = base['start_date'].apply(lambda x: transform_data(x))

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   distance       30 non-null     float64
#  1   moving_time    30 non-null     int64
#  2   elapsed_time   30 non-null     int64
#  3   type           30 non-null     object
#  4   start_date     30 non-null     object
#  5   average_speed  30 non-null     float64
#  6   max_speed      30 non-null     float64
#  7   elev_high      30 non-null     int64
#  8   elev_low       30 non-null     int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.2+ KB

# %%
base.index= pd.to_datetime(base['start_date'])

# %%
base=base.drop('start_date', 1)

# %%
base['day'] = base.index.day
base['month'] = base.index.month
base['year'] = base.index.year
base['day_of_week'] = base.index.day_of_week

# %%
base.head()
# Out:
#             distance  moving_time  elapsed_time  type  average_speed  \
# start_date
# 2021-05-07    7421.4         2382          2382   Run          3.116
# 2021-05-05    3973.0         1241          1241   Run          3.201
# 2021-05-01   61663.6         8168          8295  Ride          7.549
# 2021-04-30   39816.8         5566          5716  Ride          7.154
# 2021-04-29    4821.2         1413          1417   Run          3.412
#
#             max_speed  elev_high  elev_low  day  month  year  day_of_week
# start_date
# 2021-05-07        9.7         33         1    7      5  2021            4
# 2021-05-05        5.9         41         9    5      5  2021            2
# 2021-05-01       15.8         53        -1    1      5  2021            5
# 2021-04-30       14.0         26        -3   30      4  2021            4
# 2021-04-29        5.4         37        17   29      4  2021            3

# %% [markdown]
# week={
#    - 0: 'monday',
#    - 1: 'tuesday',
#    - 2: 'wednesday',
#    - 3: 'thursday',
#    - 4: 'friday',
#    - 5: 'saturday',
#    - 6: 'sunday'
# }

# %% [markdown]
# month_desc={
#    - 1: 'january',
#    - 2: 'february',
#    - 3: 'march',
#    - 4: 'april',
#    - 5: 'may',
#    - 6: 'june'
# }

# %%
base.head()
# Out:
#             distance  moving_time  elapsed_time  type  average_speed  \
# start_date
# 2021-05-07    7421.4         2382          2382   Run          3.116
# 2021-05-05    3973.0         1241          1241   Run          3.201
# 2021-05-01   61663.6         8168          8295  Ride          7.549
# 2021-04-30   39816.8         5566          5716  Ride          7.154
# 2021-04-29    4821.2         1413          1417   Run          3.412
#
#             max_speed  elev_high  elev_low  day  month  year  day_of_week
# start_date
# 2021-05-07        9.7         33         1    7      5  2021            4
# 2021-05-05        5.9         41         9    5      5  2021            2
# 2021-05-01       15.8         53        -1    1      5  2021            5
# 2021-04-30       14.0         26        -3   30      4  2021            4
# 2021-04-29        5.4         37        17   29      4  2021            3

# %%
#distance X type and count X type
fig, (axis1, axis2) = plt.subplots(1,2, figsize=(19,4))
sns.barplot(x='type', y='distance', data=base, ax=axis1)
sns.countplot(x='type', data=base, ax=axis2);

# %%
fig, (axis1, axis2) = plt.subplots(1,2, figsize=(20,5))
sns.barplot(x='day', y='distance', data=base, ax=axis1, hue='type')
sns.countplot(x='day', data=base, ax=axis2, hue='type');

# %%
fig, (axis1, axis2) = plt.subplots(1,2, figsize=(20,5))
sns.barplot(x='month', y='distance', data=base, ax=axis1, hue='type')
sns.countplot(x='month', data=base, ax=axis2, hue='type');

# %%
fig, (axis1, axis2) = plt.subplots(1,2, figsize=(20,5))
sns.barplot(x='year', y='distance', data=base, ax=axis1)
sns.countplot(x='year', data=base, ax=axis2, hue='type');

# %% [markdown]
# ### ----------------------------------------------
#     -

# %%
## média tempo em movimento

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 30 entries, 2021-05-07 to 2021-03-24
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   distance       30 non-null     float64
#  1   moving_time    30 non-null     int64
#  2   elapsed_time   30 non-null     int64
#  3   type           30 non-null     object
#  4   average_speed  30 non-null     float64
#  5   max_speed      30 non-null     float64
#  6   elev_high      30 non-null     int64
#  7   elev_low       30 non-null     int64
#  8   day            30 non-null     int64
#  9   month          30 non-null     int64
#  10  year           30 non-null     int64
#  11  day_of_week    30 non-null     int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 3.0+ KB

# %%
base.head()
# Out:
#             distance  moving_time  elapsed_time  type  average_speed  \
# start_date
# 2021-05-07    7421.4         2382          2382   Run          3.116
# 2021-05-05    3973.0         1241          1241   Run          3.201
# 2021-05-01   61663.6         8168          8295  Ride          7.549
# 2021-04-30   39816.8         5566          5716  Ride          7.154
# 2021-04-29    4821.2         1413          1417   Run          3.412
#
#             max_speed  elev_high  elev_low  day  month  year  day_of_week
# start_date
# 2021-05-07        9.7         33         1    7      5  2021            4
# 2021-05-05        5.9         41         9    5      5  2021            2
# 2021-05-01       15.8         53        -1    1      5  2021            5
# 2021-04-30       14.0         26        -3   30      4  2021            4
# 2021-04-29        5.4         37        17   29      4  2021            3

# %%
sns.relplot(x='elapsed_time', y='distance', hue="type", style='type', data=base, height=8.27, aspect=11.7/8.27, size='average_speed', sizes=(15, 200));

# %% [markdown]
# Objetivos:
# - ~Distancia média por mês (todas modalidades)~
# - ~Agrupar por tipo~.
# - Série histórica por ano.
# - Média das velocidades médias
# - Média das velocidades máximas.
# - Média das elevações(alto e baixo).
# - Agrupamento (k-means)

# %%
g = sns.relplot(x="distance", y="moving_time", kind="line",hue='type', height=8.27, aspect=11.7/8.27, data=base)
g.fig.autofmt_xdate()

# %%
sns.relplot(x="month", y="distance", kind="line", hue='type' ,height=8.27, aspect=11.7/8.27,data=base);

# %%
###

# %%
# 1 run
# 2 ride

# %%
serie_ride= base.loc[base['type']=='Ride']
serie_run = base.loc[base['type']=='Run']

# %%
time1 = list(range(serie_ride.shape[0]))
serie_ride['time'] = time1
# Out:
# <ipython-input-30-d468367d4526>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   serie_ride['time'] = time1

# %%
time2 = list(range(serie_run.shape[0]))
serie_run['time'] = time2
# Out:
# <ipython-input-31-8e8853f006de>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   serie_run['time'] = time2

# %%
serie_ride.describe()
# Out:
#             distance   moving_time  elapsed_time  average_speed  max_speed  \
# count      18.000000     18.000000     18.000000      18.000000  18.000000
# mean    41679.350000   5390.555556   5528.055556       7.717722  15.194444
# std     31517.822674   3954.632045   4180.415930       0.554301   1.422290
# min     18297.000000   2449.000000   2449.000000       6.980000  11.900000
# 25%     27078.100000   3246.000000   3299.250000       7.237750  14.325000
# 50%     31960.300000   4173.500000   4200.500000       7.637000  15.450000
# 75%     39018.650000   5298.000000   5380.250000       8.124250  16.200000
# max    146620.000000  18186.000000  19191.000000       8.858000  17.600000
#
#         elev_high   elev_low        day      month    year  day_of_week  \
# count   18.000000  18.000000  18.000000  18.000000    18.0    18.000000
# mean    39.500000  -1.444444  14.500000   3.888889  2021.0     3.277778
# std     33.170238   3.697729  10.738879   0.471405     0.0     1.601674
# ...

# %%
serie_run.describe()
# Out:
#            distance  moving_time  elapsed_time  average_speed  max_speed  \
# count     11.000000    11.000000     11.000000      11.000000  11.000000
# mean    6155.627273  2018.818182   2028.636364       3.064909   7.281818
# std     1899.954596   655.398019    657.913106       0.176273   2.634699
# min     3973.000000  1241.000000   1241.000000       2.717000   4.500000
# 25%     4809.750000  1516.000000   1516.000000       2.981000   5.350000
# 50%     6101.600000  1967.000000   2027.000000       3.102000   6.400000
# 75%     7240.000000  2313.000000   2319.500000       3.135000   9.000000
# max    10128.900000  3413.000000   3413.000000       3.412000  12.800000
#
#        elev_high   elev_low        day      month    year  day_of_week  \
# count  11.000000  11.000000  11.000000  11.000000    11.0    11.000000
# mean   21.727273  -8.272727  17.090909   3.909091  2021.0     2.727273
# std    13.979205  21.147534  10.034486   0.700649     0.0     1.618080
# ...

# %% [markdown]
# ### cumulative sum

# %%
run_dummies_week_day= pd.get_dummies(serie_run['day_of_week'], drop_first=True)
serie_run = pd.concat([serie_run, run_dummies_week_day], axis=1)
run_dummies_day = pd.get_dummies(serie_run['day'], drop_first=True)
serie_run = pd.concat([serie_run, run_dummies_day], axis=1)
serie_run.iloc[:3, :]
# Out:
#             distance  moving_time  elapsed_time type  average_speed  \
# start_date
# 2021-05-07    7421.4         2382          2382  Run          3.116
# 2021-05-05    3973.0         1241          1241  Run          3.201
# 2021-04-29    4821.2         1413          1417  Run          3.412
#
#             max_speed  elev_high  elev_low  day  month  ...  5  7  9  12  16  \
# start_date                                              ...
# 2021-05-07        9.7         33         1    7      5  ...  0  1  0   0   0
# 2021-05-05        5.9         41         9    5      5  ...  0  0  0   0   0
# 2021-04-29        5.4         37        17   29      4  ...  0  0  0   0   0
#
#             22  25  27  29  31
# start_date
# 2021-05-07   0   0   0   0   0
# 2021-05-05   0   0   0   0   0
# 2021-04-29   0   0   0   1   0
#
# [3 rows x 26 columns]

# %%
ride_dummies_week_day= pd.get_dummies(serie_ride['day_of_week'], drop_first=True)
serie_ride = pd.concat([serie_ride, ride_dummies_week_day], axis=1)
ride_dummies_day = pd.get_dummies(serie_ride['day'], drop_first=True)
serie_ride = pd.concat([serie_ride, ride_dummies_day], axis=1)
serie_ride.iloc[:3, :]
# Out:
#             distance  moving_time  elapsed_time  type  average_speed  \
# start_date
# 2021-05-01   61663.6         8168          8295  Ride          7.549
# 2021-04-30   39816.8         5566          5716  Ride          7.154
# 2021-04-27   31340.1         4423          4670  Ride          7.086
#
#             max_speed  elev_high  elev_low  day  month  ...  7  8  10  14  15  \
# start_date                                              ...
# 2021-05-01       15.8         53        -1    1      5  ...  0  0   0   0   0
# 2021-04-30       14.0         26        -3   30      4  ...  0  0   0   0   0
# 2021-04-27       13.9         27        -2   27      4  ...  0  0   0   0   0
#
#             20  24  27  28  30
# start_date
# 2021-05-01   0   0   0   0   0
# 2021-04-30   0   0   0   0   1
# 2021-04-27   0   0   1   0   0
#
# [3 rows x 29 columns]

# %%
serie_run['previous'] = serie_run['distance'].shift(1)
serie_run = serie_run.iloc[5:]

# %%
serie_ride['previous'] = serie_ride['distance'].shift(5)
serie_ride = serie_ride.iloc[5:]

# %%
serie_run.head()
# Out:
#             distance  moving_time  elapsed_time type  average_speed  \
# start_date
# 2021-04-12    6101.6         1967          2027  Run          3.102
# 2021-04-09    5086.4         1699          1702  Run          2.994
# 2021-04-05    6107.2         2032          2036  Run          3.006
# 2021-03-31    7058.6         2244          2257  Run          3.146
# 2021-03-27    4063.9         1496          1496  Run          2.717
#
#             max_speed  elev_high  elev_low  day  month  ...  7  9  12  16  22  \
# start_date                                              ...
# 2021-04-12       10.2          6       -65   12      4  ...  0  0   1   0   0
# 2021-04-09        5.0         10       -13    9      4  ...  0  1   0   0   0
# 2021-04-05        5.3         13        -3    5      4  ...  0  0   0   0   0
# 2021-03-31       12.8         18       -10   31      3  ...  0  0   0   0   0
# 2021-03-27        4.5         16         1   27      3  ...  0  0   0   0   0
#
# ...

# %%
serie_ride.head()
# Out:
#             distance  moving_time  elapsed_time  type  average_speed  \
# start_date
# 2021-04-15   19396.2         2779          2848  Ride          6.980
# 2021-04-15   22206.4         2906          2942  Ride          7.642
# 2021-04-14   31791.7         4366          4396  Ride          7.282
# 2021-04-10   39884.2         5582          5617  Ride          7.145
# 2021-04-08   25946.5         3119          3119  Ride          8.319
#
#             max_speed  elev_high  elev_low  day  month  ...  8  10  14  15  \
# start_date                                              ...
# 2021-04-15       16.2         23        -3   15      4  ...  0   0   0   1
# 2021-04-15       14.7         18        -2   15      4  ...  0   0   0   1
# 2021-04-14       16.2         25         1   14      4  ...  0   0   1   0
# 2021-04-10       17.6         47       -14   10      4  ...  0   1   0   0
# 2021-04-08       16.0         30         1    8      4  ...  1   0   0   0
#
# ...

# %%
serie_run.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6 entries, 2021-04-12 to 2021-03-25
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   distance       6 non-null      float64
#  1   moving_time    6 non-null      int64
#  2   elapsed_time   6 non-null      int64
#  3   type           6 non-null      object
#  4   average_speed  6 non-null      float64
#  5   max_speed      6 non-null      float64
#  6   elev_high      6 non-null      int64
#  7   elev_low       6 non-null      int64
#  8   day            6 non-null      int64
#  9   month          6 non-null      int64
#  10  year           6 non-null      int64
#  11  day_of_week    6 non-null      int64
#  12  time           6 non-null      int64
#  13  2              6 non-null      uint8
#  14  3              6 non-null      uint8
#  15  4              6 non-null      uint8
#  16  5              6 non-null      uint8
# ...

# %%
train_rate = 0.8
run_X_train = serie_run.iloc[:round(serie_run.shape[0] * train_rate), 12:]
run_X_test = serie_run.iloc[round(serie_run.shape[0] * train_rate):, 12:]

run_y_train = serie_run.iloc[:round(serie_run.shape[0] * train_rate), 0]
run_y_test = serie_run.iloc[round(serie_run.shape[0] * train_rate):, 0]
len(run_y_test)
# Out:
# 1

# %%
train_rate = 0.8
ride_X_train = serie_ride.iloc[:round(serie_ride.shape[0] * train_rate), 12:]
ride_X_test = serie_ride.iloc[round(serie_ride.shape[0] * train_rate):, 12:]

ride_y_train = serie_ride.iloc[:round(serie_ride.shape[0] * train_rate), 0]
ride_y_test = serie_ride.iloc[round(serie_ride.shape[0] * train_rate):, 0]
len(ride_y_test)
# Out:
# 3

# %%
plt.figure(figsize=(16,6))
plt.title(f'Prediction run de {len(run_y_test)} days.')
plt.plot(run_y_train)
plt.plot(run_y_test)
plt.show();

# %%
plt.figure(figsize=(16,6))
plt.title(f'Prediction ride de {len(ride_y_test)} days.')
plt.plot(ride_y_train)
plt.plot(ride_y_test)
plt.show();

# %% [markdown]
# #### validation
